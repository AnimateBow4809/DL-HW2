# %%
from utils.visualization import plot_random_samples,plot_class_distribution
from utils.mnist_utils import load_mnist_from_pkl

# %%
train_data, val_data, test_data = load_mnist_from_pkl("../data/dataset/mnist.pkl")
x_train, y_train = train_data
x_val, y_val = val_data
x_test, y_test = test_data
# Out:
# D:\large-codes\DL-HW1\utils\mnist_utils.py:8: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   data = pickle.load(f, encoding='latin1')

# %%
plot_random_samples(x_train, y_train, samples_per_class=5)

# %%
plot_class_distribution(y_train, y_val, y_test)
