# %%
import torch
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from utils.mnist_utils import load_fashion_mnist_raw
from data.data_loader import MnistDataset
from utils.visualization import plot_class_distribution
from utils.visualization import plot_random_samples
from utils.mnist_utils import load_mnist_from_pkl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 from torch.utils.data import DataLoader
#       3 import torchvision.transforms as transforms
#       4 from utils.mnist_utils import load_fashion_mnist_raw
#
# ModuleNotFoundError: No module named 'torch'

# %%
(x_train_full, y_train_full), (x_test, y_test) = load_fashion_mnist_raw(data_dir="../data/dataset/fashion")
total_size = len(x_train_full)
val_size = 10000
generator = torch.Generator().manual_seed(42)
indices = torch.randperm(total_size, generator=generator).numpy()
val_indices = indices[:val_size]
train_indices = indices[val_size:]

x_train, y_train = x_train_full[train_indices], y_train_full[train_indices]
x_val, y_val = x_train_full[val_indices], y_train_full[val_indices]

print(f"Train size: {len(x_train)}")
print(f"Val size: {len(x_val)}")
# Out:
# Train size: 50000
# Val size: 10000

# %%
plot_random_samples(x_train, y_train, samples_per_class=5)

# %%
plot_class_distribution(y_train, y_val, y_test)

# %%
(x_train, y_train), (x_val, y_val), (x_test, y_test) = load_mnist_from_pkl("../data/dataset/normal/mnist.pkl")
print(f"Train size: {len(x_train)}")
print(f"Val size: {len(x_val)}")
print(f"Val size: {len(x_test)}")
# Out:
# Train size: 50000
# Val size: 10000
# Val size: 10000
# D:\large-codes\DL-HW2\utils\mnist_utils.py:9: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   data = pickle.load(f, encoding='latin1')

# %%
plot_random_samples(x_train, y_train, samples_per_class=5)

# %%
plot_class_distribution(y_train, y_val, y_test)

# %%
dataset = MnistDataset(x_train, y_train, transform=transforms.ToTensor())
for image,label in DataLoader(dataset, batch_size=4, shuffle=True):
    print(image.shape)
    print(label.shape)
    break
# Out:
# torch.Size([4, 1, 28, 28])
# torch.Size([4])
